# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../input/iris.csv")
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
x=df[['sepal.length','sepal.width','petal.length','petal.width']]
y=df['variety']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size = 0.40)

# %%
model = tree.DecisionTreeClassifier(criterion='entropy')
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# ['Virginica' 'Setosa' 'Versicolor' 'Versicolor' 'Setosa' 'Setosa'
#  'Virginica' 'Virginica' 'Setosa' 'Setosa' 'Setosa' 'Virginica'
#  'Versicolor' 'Virginica' 'Virginica' 'Setosa' 'Virginica' 'Setosa'
#  'Setosa' 'Virginica' 'Versicolor' 'Versicolor' 'Versicolor' 'Virginica'
#  'Virginica' 'Versicolor' 'Versicolor' 'Virginica' 'Versicolor'
#  'Virginica' 'Versicolor' 'Virginica' 'Setosa' 'Versicolor' 'Setosa'
#  'Virginica' 'Setosa' 'Setosa' 'Virginica' 'Setosa' 'Setosa' 'Setosa'
#  'Setosa' 'Versicolor' 'Versicolor' 'Setosa' 'Setosa' 'Setosa' 'Setosa'
#  'Virginica' 'Setosa' 'Virginica' 'Virginica' 'Versicolor' 'Setosa'
#  'Versicolor' 'Virginica' 'Virginica' 'Setosa' 'Virginica']

# %%
plt.figure(figsize = (25,20))
fn = ['sepal.length','sepal.width','petal.length','petal.width']
cn = ['setosa','versicolor','virginica']
tree.plot_tree(model,feature_names = fn, class_names = cn, filled = True)
# Out:
# [Text(523.125, 1009.5428571428572, 'petal.length <= 2.35\nentropy = 1.574\nsamples = 90\nvalue = [26, 35, 29]\nclass = versicolor'),
#  Text(348.75, 854.2285714285715, 'entropy = 0.0\nsamples = 26\nvalue = [26, 0, 0]\nclass = setosa'),
#  Text(697.5, 854.2285714285715, 'petal.width <= 1.55\nentropy = 0.994\nsamples = 64\nvalue = [0, 35, 29]\nclass = versicolor'),
#  Text(348.75, 698.9142857142858, 'petal.length <= 5.0\nentropy = 0.316\nsamples = 35\nvalue = [0, 33, 2]\nclass = versicolor'),
#  Text(174.375, 543.6, 'entropy = 0.0\nsamples = 33\nvalue = [0, 33, 0]\nclass = versicolor'),
#  Text(523.125, 543.6, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(1046.25, 698.9142857142858, 'petal.length <= 5.05\nentropy = 0.362\nsamples = 29\nvalue = [0, 2, 27]\nclass = virginica'),
#  Text(871.875, 543.6, 'sepal.width <= 2.85\nentropy = 0.811\nsamples = 8\nvalue = [0, 2, 6]\nclass = virginica'),
#  Text(697.5, 388.28571428571433, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4]\nclass = virginica'),
#  Text(1046.25, 388.28571428571433, 'sepal.width <= 3.1\nentropy = 1.0\nsamples = 4\nvalue = [0, 2, 2]\nclass = versicolor'),
#  Text(871.875, 232.97142857142865, 'petal.length <= 4.95\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(697.5, 77.65714285714284, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(1046.25, 77.65714285714284, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(1220.625, 232.97142857142865, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(1220.625, 543.6, 'entropy = 0.0\nsamples = 21\nvalue = [0, 0, 21]\nclass = virginica')]

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        24
#   Versicolor       0.93      0.93      0.93        15
#    Virginica       0.95      0.95      0.95        21
#
#     accuracy                           0.97        60
#    macro avg       0.96      0.96      0.96        60
# weighted avg       0.97      0.97      0.97        60
